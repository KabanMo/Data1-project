# %% [markdown]
# # Extracting data using Spotify API

# %%
# Installing and importing packages

# !pip3 install requests
import requests
import json
import csv
# Out:
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.30.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (2022.12.7)
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Substitute following variables with adequate clientID and clientSecret and access Spotify API

# %%
# Passwords

CLIENT_ID = 'clientID'
CLIENT_SECRET = 'clientSecret'

# %%
### ACCESSING THE API


AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']


headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}


# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# %% [markdown]
# We want to obtain data from the TOP 50 playlists for USA, UK, Australia, India and South Africa. PlaylistIDs were directly obtained from Spotify (https://open.spotify.com) and added into a dictionary

# %%
# Creating a library with the playlists ID from the URI for Global and desired countries TOP 50 playlists 

playlists_ids = {'Global':'37i9dQZEVXbNG2KDcFcKOF?si=482439e7bff944eb',
                 'USA': '37i9dQZEVXbLp5XoPON0wI?si=8edfde91af67406c',
                 'UK': '37i9dQZEVXbMwmF30ppw50?si=b5175b30cb7b46e3',
                 'Australia':'37i9dQZEVXbJPcfkRz0wJ0?si=7890479cf740436c',
                 'India':'37i9dQZEVXbLZ52XmnySJg?si=0773e9ef03684046',
                 'South Africa': '37i9dQZEVXbJV3H3OfCN1z?si=759621de52964d16',
                }

# %% [markdown]
# Using GET from library request, we iterated through the dictionary in order to obtain data for all the songs in each playlist.

# %%
### GETTING THE DATA about the playlist with GET request

d= {}   # New dictionary to store data

for key in playlists_ids:
    r = requests.get(BASE_URL + 'playlists/' + playlists_ids[key], headers=headers)
    d[f"{key}"] = r.json()

# %%
# Checking all tracks for each playlist

for country in d:
    print (f"{country} \n")
    
    country_playlist = d[country]['tracks']
    for i in country_playlist['items']:
        print (i['track']['name'],'-------', i['track']['album']['artists'][0]['name'],'-------', i['track']['popularity'])
    
    print ("\n")
# Out:
# Global
#
# Ella Baila Sola ------- Eslabon Armado ------- 90
# un x100to ------- Grupo Frontera ------- 100
# La Bebe - Remix ------- Yng Lvcas ------- 99
# Cupid - Twin Ver. ------- FIFTY FIFTY ------- 98
# Flowers ------- Miley Cyrus ------- 91
# Daylight ------- David Kushner ------- 97
# Kill Bill ------- SZA ------- 94
# As It Was ------- Harry Styles ------- 92
# TQG ------- KAROL G ------- 96
# Classy 101 ------- Feid ------- 95
# Tattoo ------- Loreen ------- 91
# PRC ------- Peso Pluma ------- 96
# BESO ------- ROSALÍA ------- 96
# El Azul ------- Junior H ------- 95
# Creepin' (with The Weeknd & 21 Savage) ------- Metro Boomin ------- 96
# See You Again (feat. Kali Uchis) ------- Tyler, The Creator ------- 94
# Calm Down (with Selena Gomez) ------- Rema ------- 79
# Yandel 150 ------- Yandel ------- 90
# Die For You (with Ariana Grande) - Remix ------- The Weeknd ------- 88
# Cha Cha Cha ------- Käärijä ------- 88
# Boy's a Liar Pt. 2 ------- PinkPantheress ------- 96
# Anti-Hero ------- Taylor Swift ------- 94
# Last Night ------- Morgan Wallen ------- 89
# Die For You ------- The Weeknd ------- 91
# AMG ------- Natanael Cano ------- 95
# I Wanna Be Yours ------- Arctic Monkeys ------- 94
# All My Life (feat. J. Cole) ------- Lil Durk ------- 87
# I'm Good (Blue) ------- David Guetta ------- 94
# Like Crazy ------- Jimin ------- 93
# Acróstico ------- Shakira ------- 86
# Here With Me ------- d4vd ------- 94
# Angels Like You ------- Miley Cyrus ------- 91
# golden hour ------- JVKE ------- 90
# Until I Found You (with Em Beihold) - Em Beihold Version ------- Stephen Sanchez ------- 93
# Shakira: Bzrp Music Sessions, Vol. 53 ------- Bizarrap ------- 95
# Por las Noches ------- Peso Pluma ------- 93
# Moonlight ------- Kali Uchis ------- 87
# Unholy (feat. Kim Petras) ------- Sam Smith ------- 86
# Another Love ------- Tom Odell ------- 63
# Cruel Summer ------- Taylor Swift ------- 92
# Starboy ------- The Weeknd ------- 93
# I Ain't Worried ------- OneRepublic ------- 55
# Hey Mor ------- Ozuna ------- 91
# La Bachata ------- Manuel Turizo ------- 86
# People ------- Libianca ------- 92
# The Planet ------- BTS ------- 86
# El Gordo Trae El Mando ------- Chino Pacas ------- 92
# FLOWER ------- JISOO ------- 86
# Mockingbird ------- Eminem ------- 92
# Frágil ------- Yahritza Y Su Esencia ------- 90
#
#
# USA
#
# Ella Baila Sola ------- Eslabon Armado ------- 90
# Last Night ------- Morgan Wallen ------- 89
# All My Life (feat. J. Cole) ------- Lil Durk ------- 87
# un x100to ------- Grupo Frontera ------- 100
# Kill Bill ------- SZA ------- 94
# See You Again (feat. Kali Uchis) ------- Tyler, The Creator ------- 94
# Cupid - Twin Ver. ------- FIFTY FIFTY ------- 98
# La Bebe - Remix ------- Yng Lvcas ------- 99
# Boy's a Liar Pt. 2 ------- PinkPantheress ------- 96
# Search & Rescue ------- Drake ------- 91
# MATHEMATICAL DISRESPECT ------- Lil Mabu ------- 86
# PRC ------- Peso Pluma ------- 96
# Area Codes ------- Kali ------- 84
# Fast Car ------- Luke Combs ------- 89
# Flowers ------- Miley Cyrus ------- 91
# You Proof ------- Morgan Wallen ------- 86
# Cruel Summer ------- Taylor Swift ------- 92
# Anti-Hero ------- Taylor Swift ------- 94
# SLUT ME OUT ------- NLE Choppa ------- 75
# AMG ------- Natanael Cano ------- 95
# Daylight ------- David Kushner ------- 97
# Por las Noches ------- Peso Pluma ------- 93
# Thinkin’ Bout Me ------- Morgan Wallen ------- 87
# Wasted On You ------- Morgan Wallen ------- 86
# El Azul ------- Junior H ------- 95
# Creepin' (with The Weeknd & 21 Savage) ------- Metro Boomin ------- 96
# No Role Modelz ------- J. Cole ------- 90
# Superhero (Heroes & Villains) [with Future & Chris Brown] ------- Metro Boomin ------- 90
# Something in the Orange ------- Zach Bryan ------- 88
# Moonlight ------- Kali Uchis ------- 87
# golden hour ------- JVKE ------- 90
# As It Was ------- Harry Styles ------- 92
# El Gordo Trae El Mando ------- Chino Pacas ------- 92
# Just Wanna Rock ------- Lil Uzi Vert ------- 90
# Karma ------- Taylor Swift ------- 88
# Rich Flex ------- Drake ------- 90
# Die For You ------- The Weeknd ------- 91
# Sure Thing ------- Miguel ------- 91
# Calm Down (with Selena Gomez) ------- Rema ------- 79
# Trance (with Travis Scott & Young Thug) ------- Metro Boomin ------- 90
# Bad Habit ------- Steve Lacy ------- 85
# Money Trees ------- Kendrick Lamar ------- 84
# Snooze ------- SZA ------- 92
# One Thing At A Time ------- Morgan Wallen ------- 82
# Jimmy Cooks (feat. 21 Savage) ------- Drake ------- 89
# Chemical ------- Post Malone ------- 90
# Romantic Homicide ------- d4vd ------- 91
# Princess Diana (with Nicki Minaj) ------- Ice Spice ------- 87
# Lavender Haze ------- Taylor Swift ------- 88
# Watch This - ARIZONATEARS Pluggnb Remix ------- Lil Uzi Vert ------- 89
#
#
# UK
#
# Daylight ------- David Kushner ------- 97
# Tattoo ------- Loreen ------- 91
# Miracle (with Ellie Goulding) ------- Calvin Harris ------- 91
# Cha Cha Cha ------- Käärijä ------- 88
# Flowers ------- Miley Cyrus ------- 91
# Boy's a Liar Pt. 2 ------- PinkPantheress ------- 96
# People ------- Libianca ------- 92
# Kill Bill ------- SZA ------- 94
# Wish You The Best ------- Lewis Capaldi ------- 87
# Eyes Closed ------- Ed Sheeran ------- 81
# Queen of Kings ------- Alessandra ------- 86
# Anti-Hero ------- Taylor Swift ------- 94
# Cupid - Twin Ver. ------- FIFTY FIFTY ------- 98
# As It Was ------- Harry Styles ------- 92
# Giving Me ------- Jazzy ------- 77
# REACT ------- Switch Disco ------- 79
# Escapism. ------- RAYE ------- 91
# Chemical ------- Post Malone ------- 90
# See You Again (feat. Kali Uchis) ------- Tyler, The Creator ------- 94
# Calm Down (with Selena Gomez) ------- Rema ------- 79
# ceilings ------- Lizzy McAlpine ------- 91
# MATHEMATICAL DISRESPECT ------- Lil Mabu ------- 86
# Dog Days Are Over ------- Florence + The Machine ------- 83
# All My Life (feat. J. Cole) ------- Lil Durk ------- 87
# I Wrote A Song ------- Mae Muller ------- 77
# Creepin' (with The Weeknd & 21 Savage) ------- Metro Boomin ------- 96
# Hell N Back ------- Bakar ------- 73
# If We Ever Broke Up ------- Mae Stephens ------- 88
# I Ain't Worried ------- OneRepublic ------- 55
# Sure Thing ------- Miguel ------- 91
# Mr. Brightside ------- The Killers ------- 87
# I'm Good (Blue) ------- David Guetta ------- 94
# Forget Me ------- Lewis Capaldi ------- 84
# Another Love ------- Tom Odell ------- 63
# Search & Rescue ------- Drake ------- 91
# CUFF IT ------- Beyoncé ------- 89
# Cruel Summer ------- Taylor Swift ------- 92
# Players ------- Coi Leray ------- 92
# Baby Don't Hurt Me ------- David Guetta ------- 90
# Riptide ------- Vance Joy ------- 85
# No Role Modelz ------- J. Cole ------- 90
# Viva La Vida ------- Coldplay ------- 88
# messy in heaven ------- venbee ------- 77
# Someone You Loved ------- Lewis Capaldi ------- 89
# Last Night ------- Morgan Wallen ------- 89
# Afraid To Feel ------- LF SYSTEM ------- 81
# Tony Soprano 2 ------- Nines ------- 67
# golden hour ------- JVKE ------- 90
# Sweater Weather ------- The Neighbourhood ------- 91
# Everybody Wants To Rule The World ------- Tears For Fears ------- 88
#
#
# Australia
#
# Last Night ------- Morgan Wallen ------- 89
# Flowers ------- Miley Cyrus ------- 91
# Boy's a Liar Pt. 2 ------- PinkPantheress ------- 96
# Cupid - Twin Ver. ------- FIFTY FIFTY ------- 98
# Daylight ------- David Kushner ------- 97
# Fast Car ------- Luke Combs ------- 89
# Kill Bill ------- SZA ------- 94
# As It Was ------- Harry Styles ------- 92
# Creepin' (with The Weeknd & 21 Savage) ------- Metro Boomin ------- 96
# Anti-Hero ------- Taylor Swift ------- 94
# All My Life (feat. J. Cole) ------- Lil Durk ------- 87
# I Ain't Worried ------- OneRepublic ------- 55
# Players ------- Coi Leray ------- 92
# Miracle (with Ellie Goulding) ------- Calvin Harris ------- 91
# MATHEMATICAL DISRESPECT ------- Lil Mabu ------- 86
# Something in the Orange ------- Zach Bryan ------- 88
# See You Again (feat. Kali Uchis) ------- Tyler, The Creator ------- 94
# Riptide ------- Vance Joy ------- 85
# Escapism. ------- RAYE ------- 91
# You Proof ------- Morgan Wallen ------- 86
# Until I Found You (with Em Beihold) - Em Beihold Version ------- Stephen Sanchez ------- 93
# Eyes Closed ------- Ed Sheeran ------- 81
# Area Codes ------- Kali ------- 84
# Heat Waves ------- Glass Animals ------- 90
# Say Yes To Heaven ------- Lana Del Rey ------- 77
# Chemical ------- Post Malone ------- 90
# Die For You (with Ariana Grande) - Remix ------- The Weeknd ------- 88
# I'm Good (Blue) ------- David Guetta ------- 94
# The Kind of Love We Make ------- Luke Combs ------- 82
# Calm Down (with Selena Gomez) ------- Rema ------- 79
# Unholy (feat. Kim Petras) ------- Sam Smith ------- 86
# Shivers ------- Ed Sheeran ------- 67
# No Role Modelz ------- J. Cole ------- 90
# Wish You The Best ------- Lewis Capaldi ------- 56
# Green Green Grass ------- George Ezra ------- 83
# Mr. Brightside ------- The Killers ------- 87
# Someone You Loved ------- Lewis Capaldi ------- 89
# Snooze ------- SZA ------- 92
# Cruel Summer ------- Taylor Swift ------- 92
# Never Felt So Alone ------- Labrinth ------- 75
# Die For You ------- The Weeknd ------- 91
# 10:35 ------- Tiësto ------- 74
# Rhyme Dust ------- MK ------- 78
# ceilings ------- Lizzy McAlpine ------- 91
# Sure Thing ------- Miguel ------- 91
# Money Trees ------- Kendrick Lamar ------- 84
# golden hour ------- JVKE ------- 90
# Viva La Vida ------- Coldplay ------- 88
# Dreams - 2004 Remaster ------- Fleetwood Mac ------- 85
# People ------- Libianca ------- 92
#
#
# India
#
# Maan Meri Jaan ------- King ------- 86
# O Bedardeya (From "Tu Jhoothi Main Makkaar") ------- Pritam ------- 85
# Kesariya ------- Pritam ------- 78
# Kahani Suno 2.0 ------- Kaifi Khalil ------- 85
# Malang Sajna ------- Sachet Tandon ------- 83
# Tere Pyaar Mein ------- Pritam ------- 84
# Agar Tum Saath Ho (From "Tamasha") ------- Arijit Singh ------- 78
# Jhoome Jo Pathaan ------- Vishal-Shekhar ------- 84
# Obsessed ------- Riar Saab ------- 72
# Daku ------- Chani Nattan ------- 82
# Tu Aake Dekhle ------- King ------- 82
# Rubicon Drill ------- Laddi Chahal ------- 80
# Tere Hawaale (From "Laal Singh Chaddha") ------- Pritam ------- 76
# Pyaar Hota Kayi Baar Hai (From "Tu Jhoothi Main Makkaar") ------- Pritam ------- 82
# Baller ------- Ikky ------- 82
# Raataan Lambiyan (From "Shershaah") ------- Tanishk Bagchi ------- 79
# No Love ------- Shubh ------- 82
# Besharam Rang (From "Pathaan") ------- Vishal-Shekhar ------- 81
# Mi Amor ------- Sharn ------- 80
# Chaand Baaliyan ------- Aditya A ------- 80
# Tujhe Kitna Chahne Lage (From "Kabir Singh") ------- Arijit Singh ------- 76
# Cupid - Twin Ver. ------- FIFTY FIFTY ------- 98
# Thaa ------- Varinder Brar ------- 79
# Ranjha (From "Shershaah") ------- Various Artists ------- 79
# Kya Loge Tum ------- B Praak ------- 65
# Mann Mera ------- Gajendra Verma ------- 77
# Haath Varthi ------- MC STAN ------- 73
# SPAIN ------- Jassa Dhillon ------- 79
# Shayad ------- Pritam ------- 77
# Humdard (From "Ek Villain") ------- Arijit Singh ------- 73
# Phir Aur Kya Chahiye ------- Sachin-Jigar ------- 62
# Kaise Hua (From "Kabir Singh") ------- Vishal Mishra ------- 75
# Starboy ------- The Weeknd ------- 93
# Calm Down (with Selena Gomez) ------- Rema ------- 79
# Manjha ------- Vishal Mishra ------- 77
# Manike (From "Thank God") ------- Yohani ------- 80
# Rang Lageya ------- Mohit Chauhan ------- 78
# Tum Se Hi ------- Pritam ------- 79
# Jeena Jeena ------- Sachin-Jigar ------- 76
# TERE TE ------- Various Artists ------- 78
# 295 ------- Sidhu Moose Wala ------- 79
# Excuses ------- AP Dhillon ------- 80
# Haryana Hood ------- Irshad Khan ------- 71
# Asal Mein ------- Darshan Raval ------- 75
# Ajab Si (From "Om Shanti Om") ------- KK ------- 72
# Saibo ------- Sachin-Jigar ------- 78
# Kali Kali Zulfon Ke (Lo-Fi) ------- Madhur Sharma ------- 74
# Deva Deva ------- Pritam ------- 66
# Pal ------- Javed-Mohsin ------- 76
# Kabira ------- Pritam ------- 78
#
#
# South Africa
#
# Mnike (feat. DJ Maphorisa, Nandipha808, Ceeka RSA & Tyron Dee) ------- Tyler ICU ------- 68
# All My Life (feat. J. Cole) ------- Lil Durk ------- 87
# Hamba Juba ------- Various Artists ------- 67
# Umbayimbayi ------- Inkabi Zezwe ------- 50
# Stimela ------- 2Point1 ------- 65
# Yahyuppiyah (feat. Pcee, EeQue & Chley) ------- Uncle Waffles ------- 59
# Mina Nawe ------- Soa mattrix ------- 64
# Calm Down (with Selena Gomez) ------- Rema ------- 79
# People ------- Libianca ------- 92
# Bhebha (feat. Myztro, Mellow & Sleazy, QuayR Musiq & Matuteboy) ------- Shaunmusiq ------- 64
# NGIMOJA (feat. Khanyisa, Tumelo_za & Tyrondee) ------- Tyler ICU ------- 63
# Rush ------- Ayra Starr ------- 82
# Fatela ------- Aymos ------- 63
# iMpumelelo ------- Sam Deep ------- 60
# Khaya Lami ------- Inkabi Zezwe ------- 57
# Sosh Plata - Remix ------- Loatinover Pounds ------- 59
# Kwelinye (feat. Keynote) ------- Mellow & Sleazy ------- 47
# Gangnam Style (feat. DJ Maphorisa & Kabza De Small) ------- Mas Musiq ------- 51
# Kilimanjaro (feat. Justin99, Mema_Percent & Mr JazziQ) ------- Pcee ------- 64
# Sukakude ------- Kelvin Momo ------- 61
# Sure Thing ------- Miguel ------- 91
# Wena Dali ------- Murumba Pitch ------- 58
# Ngiyeza ------- Lwah Ndlunkulu ------- 59
# yey ------- uLazi ------- 58
# Area Codes ------- Kali ------- 84
# Snooze ------- SZA ------- 92
# Company ------- AKA ------- 56
# Daylight ------- David Kushner ------- 97
# Search & Rescue ------- Drake ------- 91
# Thath'Indawo (Live) ------- Spirit Of Praise ------- 57
# Shona Kwelanga (feat. Mawhoo, Da Muziqal Chef & Kabza De Small) ------- DJ Maphorisa ------- 60
# Flowers ------- Miley Cyrus ------- 91
# Myztro Ah Ah (feat. Xduppy, ShaunMusiQ & Ftears) ------- Myztro ------- 52
# Creepin' (with The Weeknd & 21 Savage) ------- Metro Boomin ------- 96
# Last Last ------- Burna Boy ------- 81
# Kill Bill ------- SZA ------- 94
# Intro (Inkabi Zezwe) ------- Inkabi Zezwe ------- 50
# Sengizwile (feat. Aymos & Young Stunna) ------- Mas Musiq ------- 60
# Under The Influence ------- Chris Brown ------- 91
# WAIT FOR U (feat. Drake & Tems) ------- Future ------- 87
# Johnny ke Johnny (feat. Papi_SA) ------- Pcee ------- 58
# Strike (Holster) ------- Lil Yachty ------- 80
# Mohigan Sun ------- MÖRDA ------- 57
# Boy's a Liar Pt. 2 ------- PinkPantheress ------- 96
# When I See U ------- Fantasia ------- 73
# Lemons (Lemonade) ------- AKA ------- 55
# No Role Modelz ------- J. Cole ------- 90
# Ithuba ------- Lwah Ndlunkulu ------- 57
# Esangweni ------- Murumba Pitch ------- 57
# SETE (feat. Young Stunna & Blxckie) ------- K.O ------- 55

# %% [markdown]
# Now, using some of the data from the playlist information, we want to extract the audio features of each of the tracks, as well as the artist genre and the date in which the album was released.
#
# In order to do this, we need to do three more calls to Spotify API

# %% [markdown]
# ### THE FOLLOWING CODE WILL TAKE SOME TIME:
#
# Data used for the analysis was extracted and store using this code. Move to analysis.ipynb to continue with the analysis

# %%
data = [] #store final data

tracks_id = []


for country in d:
    
    print (f"{country} \n")  # Keeping track of the iterations in the loop
    
    country_playlist = d[country]['tracks']
    
    for song in country_playlist['items']:
    
        track_id = song['track']['id']
    
        track_name = song['track']['name']
    
        track_popularity = song['track']['popularity']
    
        track_artist = song['track']['artists'][0]['name']
        

        """
        GET requests to the API to get the relevant info needed:
        
        """
        
        # Getting album_id and artist_id to obtain info about the artist and the album
    
        r1 = requests.get(BASE_URL + 'tracks/' + track_id, headers=headers)
        tracks = r1.json()
    
        album_id = tracks['album']['id']
        artist_id = tracks['album']['artists'][0]['id']
        
        
        # Getting info about the album release date using album_id obtained in r1
        
        r2 = requests.get(BASE_URL + 'albums/' + album_id, headers=headers)
        album = r2.json()
   
        album_release = album['release_date']
    
    
        # Getting info about artists genre using artist_id obtained in r1
    
        r3 = requests.get(BASE_URL + 'artists/' + artist_id, headers=headers)
        artist = r3.json()
    
        artist_genre = artist['genres']
        
    
        # Getting audio features (key, liveness, danceability, ...)

        f = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)
        f = f.json()
            

        # Combine with info obtained previously:
            
        f.update({
            'country_playlist': country,
            'track_name': track_name,
            'popularity': track_popularity,
            'artist': track_artist,
            'artist_genres': artist_genre,
            'album_release': album_release

            })
            

        data.append(f)
# Out:
# Global
#
# USA
#
# UK
#
# Australia
#
# India
#
# South Africa

# %% [markdown]
# Data is saved into a json file for reproducibility and validation purposes

# %%
### SAVING THE DATA

with open("playlists.json", "w") as file:
    json.dump(data, file)
